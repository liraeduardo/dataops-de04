# %%
import mysql.connector
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
con = mysql.connector.connect(
            user='root', password=os.environ['DB_PASSWORD'], port="3306", host = 'localhost', database='db')

# %%
query = """
SELECT * FROM db.cadastro;
"""

# %%
pd.read_sql(query, con)
# Out:
# /tmp/ipykernel_3161/1605690232.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, con)
#     id    sexo titulo      nome  sobrenome      cidade            estado  \
# 0    1    male     Mr     heldo     campos    parnaíba           roraima
# 1    2  female    Mrs   candice       long  las cruces    south carolina
# 2    3    male     Mr     آرسین  سهيلي راد      آبادان           کردستان
# 3    4    male     Mr   olivier        liu      inwood  british columbia
# 4    5    male     Mr     jared      wells    skerries       dublin city
# 5    6  female    Mrs      lily     vestøl       sauda            bergen
# 6    7    male     Mr     momir     terzić      arilje       south bačka
# 7    8    male     Mr     isaac       sanz  alcobendas         cantabria
# 8    9  female   Miss     abril   iglesias  teloloapan         queretaro
# 9   10    male     Mr  roboredo  rodrigues     itabira              pará
# 10  11    male     Mr     heldo     campos    parnaíba           roraima
# 11  12  female    Mrs   candice       long  las cruces    south carolina
# 12  13    male     Mr     آرسین  سهيلي راد      آبادان           کردستان
# 13  14    male     Mr   olivier        liu      inwood  british columbia
# 14  15    male     Mr     jared      wells    skerries       dublin city
# 15  16  female    Mrs      lily     vestøl       sauda            bergen
# 16  17    male     Mr     momir     terzić      arilje       south bačka
# 17  18    male     Mr     isaac       sanz  alcobendas         cantabria
# 18  19  female   Miss     abril   iglesias  teloloapan         queretaro
# 19  20    male     Mr  roboredo  rodrigues     itabira              pará
# 20  21    male     Mr     heldo     campos    parnaíba           roraima
# 21  22  female    Mrs   candice       long  las cruces    south carolina
# 22  23    male     Mr     آرسین  سهيلي راد      آبادان           کردستان
# 23  24    male     Mr   olivier        liu      inwood  british columbia
# 24  25    male     Mr     jared      wells    skerries       dublin city
# 25  26  female    Mrs      lily     vestøl       sauda            bergen
# 26  27    male     Mr     momir     terzić      arilje       south bačka
# 27  28    male     Mr     isaac       sanz  alcobendas         cantabria
# 28  29  female   Miss     abril   iglesias  teloloapan         queretaro
# 29  30    male     Mr  roboredo  rodrigues     itabira              pará
# 30  31    male     Mr     heldo     campos    parnaíba           roraima
# 31  32  female    Mrs   candice       long  las cruces    south carolina
# 32  33    male     Mr     آرسین  سهيلي راد      آبادان           کردستان
# 33  34    male     Mr   olivier        liu      inwood  british columbia
# 34  35    male     Mr     jared      wells    skerries       dublin city
# 35  36  female    Mrs      lily     vestøl       sauda            bergen
# 36  37    male     Mr     momir     terzić      arilje       south bačka
# 37  38    male     Mr     isaac       sanz  alcobendas         cantabria
# 38  39  female   Miss     abril   iglesias  teloloapan         queretaro
# 39  40    male     Mr  roboredo  rodrigues     itabira              pará
#
#              pais nacionalidade                        email data_nascimento  \
# 0          brazil            br        heldocamposexamplecom      1968-03-29
# 1   united states            us        candicelongexamplecom      1964-06-01
# 2            iran            ir       arsynshylyrdexamplecom      1955-01-12
# 3          canada            ca         olivierliuexamplecom      1976-06-22
# 4         ireland            ie         jaredwellsexamplecom      1963-07-10
# 5          norway            no         lilyvestolexamplecom      1954-06-10
# 6          serbia            rs        momirterzicexamplecom      1950-07-14
# 7           spain            es          isaacsanzexamplecom      1987-04-10
# 8          mexico            mx      abriliglesiasexamplecom      1956-08-05
# 9          brazil            br  roboredorodriguesexamplecom      1991-07-28
