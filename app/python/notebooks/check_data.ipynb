# %%
import mysql.connector
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
con = mysql.connector.connect(
            user='root', 
            password=os.environ['DB_PASSWORD'], 
            port="3306", 
            host = 'localhost', 
            database='db'
            )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 con = mysql.connector.connect(
#       2             user='root',
# ----> 3             password=os.environ['DB_PASSWORD'],
#       4             port="3306",
#       5             host = 'localhost',
#       6             database='db'
#       7             )
#
# File <frozen os>:685, in __getitem__(self, key)
#
# KeyError: 'DB_PASSWORD'

# %%
query = """
SELECT * FROM db.cadastro;
"""

# %%
pd.read_sql(query, con)
# Out:
# /tmp/ipykernel_8065/1605690232.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, con)
#    id    sexo titulo      nome  sobrenome      cidade            estado  \
# 0   1    male     Mr     heldo     campos    parnaíba           roraima
# 1   2  female    Mrs   candice       long  las cruces    south carolina
# 2   3    male     Mr     آرسین  سهيلي راد      آبادان           کردستان
# 3   4    male     Mr   olivier        liu      inwood  british columbia
# 4   5    male     Mr     jared      wells    skerries       dublin city
# 5   6  female    Mrs      lily     vestøl       sauda            bergen
# 6   7    male     Mr     momir     terzić      arilje       south bačka
# 7   8    male     Mr     isaac       sanz  alcobendas         cantabria
# 8   9  female   Miss     abril   iglesias  teloloapan         queretaro
# 9  10    male     Mr  roboredo  rodrigues     itabira              pará
#
#             pais nacionalidade                        email data_nascimento  \
# 0         brazil            br        heldocamposexamplecom      1968-03-29
# 1  united states            us        candicelongexamplecom      1964-06-01
# 2           iran            ir       arsynshylyrdexamplecom      1955-01-12
# 3         canada            ca         olivierliuexamplecom      1976-06-22
# 4        ireland            ie         jaredwellsexamplecom      1963-07-10
# 5         norway            no         lilyvestolexamplecom      1954-06-10
# 6         serbia            rs        momirterzicexamplecom      1950-07-14
# 7          spain            es          isaacsanzexamplecom      1987-04-10
# 8         mexico            mx      abriliglesiasexamplecom      1956-08-05
# 9         brazil            br  roboredorodriguesexamplecom      1991-07-28
#
#      telefone     celular  load_date
# 0  7769720550  6388424673 2024-04-27
# 1  4854554654  7987172896 2024-04-27
# 2  8584292496  9210392227 2024-04-27
# 3    10547288    88982880 2024-04-27
# 4   111298215   818419329 2024-04-27
# 5    68389753    42031964 2024-04-27
# 6   316110370   648388481 2024-04-27
# 7   991226828   655952683 2024-04-27
# 8  6061309757  6858109013 2024-04-27
# 9  4048763923  9664802987 2024-04-27
